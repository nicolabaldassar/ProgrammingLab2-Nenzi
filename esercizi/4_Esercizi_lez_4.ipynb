# %% [markdown]
# ## 1. La legge dei grandi numeri
#
# La legge dei grandi numeri è un teorema fondamentale della teoria della probabilità che indica che se ripetiamo molte volte (tendendo all'infinito) lo stesso esperimento, la frequenza di un certo evento tende ad essere costante.
#
# Vale a dire, **la legge dei grandi numeri indica che se lo stesso test viene eseguito ripetutamente (ad esempio, lancio di una moneta), la frequenza con cui si ripeterà un determinato evento (testa/croce) si avvicinerà a una costante. Questa a sua volta sarà la probabilità che questo evento si verifichi.**
#
# Fonte: https://it.economy-pedia.com/11038376-law-of-the-big-numbers
#
# - Scrivere una funzione che simula il lancio di una moneta per N volte e restituisce la frequenza % di volte che è uscita testa.
# - Calcolare la frequenza % con la grandezze del campione (numero di lanci) che varia 100 volte da 10 a 20000. Ottengo quindi 100 valori.
# - Fare il plot del Numero medio di teste (y) rispetto alla grandezza del campione (x)

# %% [markdown]
# - Scrivere una funzione che simula il lancio di una moneta per N volte e restituisce la frequenza % di volte che è uscita testa.

# %%
import numpy as np
N = 10000000
#1 = testa          0 = croce
risultati = np.random.randint(0, 2, N)
teste = risultati.sum()
perc = (teste*100)/N
print(f"{perc}%")
# Out:
# 50.00746%

# %% [markdown]
# - Calcolare la frequenza % con la grandezze del campione (numero di lanci) che varia 100 volte da 10 a 20000. Ottengo quindi 100 valori.
# - Fare il plot del Numero medio di teste (y) rispetto alla grandezza del campione (x)

# %%
import matplotlib.pyplot as plt

risultati = {"N":[], "freq":[]}
for N in np.arange(10, 20000, 100):
    risultati["N"].append(N)
    r = np.random.randint(0, 2, N)
    teste = r.sum()
    perc = (teste*100)/N
    risultati["freq"].append(perc)
print(risultati)

plt.figure(figsize=(10,6))
plt.plot(risultati["N"], risultati["freq"],label='numero di testa rispetto alla grandezza del campione')
plt.xlabel('numero di lanci')
plt.ylabel('% teste')
plt.axhline(y=50, color='red')
# Out:
# {'N': [np.int64(10), np.int64(110), np.int64(210), np.int64(310), np.int64(410), np.int64(510), np.int64(610), np.int64(710), np.int64(810), np.int64(910), np.int64(1010), np.int64(1110), np.int64(1210), np.int64(1310), np.int64(1410), np.int64(1510), np.int64(1610), np.int64(1710), np.int64(1810), np.int64(1910), np.int64(2010), np.int64(2110), np.int64(2210), np.int64(2310), np.int64(2410), np.int64(2510), np.int64(2610), np.int64(2710), np.int64(2810), np.int64(2910), np.int64(3010), np.int64(3110), np.int64(3210), np.int64(3310), np.int64(3410), np.int64(3510), np.int64(3610), np.int64(3710), np.int64(3810), np.int64(3910), np.int64(4010), np.int64(4110), np.int64(4210), np.int64(4310), np.int64(4410), np.int64(4510), np.int64(4610), np.int64(4710), np.int64(4810), np.int64(4910), np.int64(5010), np.int64(5110), np.int64(5210), np.int64(5310), np.int64(5410), np.int64(5510), np.int64(5610), np.int64(5710), np.int64(5810), np.int64(5910), np.int64(6010), np.int64(6110), np.int64(6
# ...

# %% [markdown]
# ## 2. Analisi del Dataset Titanic
# - Quante righe e colonne ha il dataset?
# - Controlla quanti valori mancanti ci sono per colonna
# - Riempi i valori mancanti nella colonna 'Embarked' con il valore più frequente
# - Rimuovi le righe dove il valore di 'Age' è mancante
# - Controlla se ci sono righe duplicate
# - Calcola l'età media dei passeggeri per ogni classe (`Pclass`), se ci sono valori mancanti di età riempili con il valore medio
# - Visualizza la distribuzione dell'età per classe
# - Visualizza la distribuzione dell'età per classe dividendo e mmostrando insieme i dati di uomini e donne

# %%
# 📦 Caricamento del dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# - Quante righe e colonne ha il dataset?

# %%
len(df.columns)
# Out:
# 12

# %% [markdown]
# - Controlla quanti valori mancanti ci sono per colonna

# %%
colonne = df.columns
for colonna in colonne:
    mancanti = df[colonna].isna().sum()
    print(f"In '{colonna}' mancano {mancanti} valori")
# Out:
# In 'PassengerId' mancano 0 valori
# In 'Survived' mancano 0 valori
# In 'Pclass' mancano 0 valori
# In 'Name' mancano 0 valori
# In 'Sex' mancano 0 valori
# In 'Age' mancano 177 valori
# In 'SibSp' mancano 0 valori
# In 'Parch' mancano 0 valori
# In 'Ticket' mancano 0 valori
# In 'Fare' mancano 0 valori
# In 'Cabin' mancano 687 valori
# In 'Embarked' mancano 2 valori

# %% [markdown]
# - Riempi i valori mancanti nella colonna 'Embarked' con il valore più frequente

# %%
moda = df['Embarked'].mode()[0] #lo 0 è per prenderne solo una in caso di parità
df['Embarked'] = df['Embarked'].fillna(moda)

# %% [markdown]
# - Rimuovi le righe dove il valore di 'Age' è mancante

# %%
df['Age'].dropna()
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 714, dtype: float64

# %% [markdown]
# - Controlla se ci sono righe duplicate

# %%
df.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# - Calcola l'età media dei passeggeri per ogni classe (`Pclass`), se ci sono valori mancanti di età riempili con il valore medio

# %%
media1 = df[df['Pclass'] == 1]['Age'].mean()
media2 = df[df['Pclass'] == 2]['Age'].mean()
media3 = df[df['Pclass'] == 3]['Age'].mean()
df[df['Pclass'] == 1] = df[df['Pclass'] == 1].fillna(media1)
df[df['Pclass'] == 2] = df[df['Pclass'] == 2].fillna(media2)
df[df['Pclass'] == 3] = df[df['Pclass'] == 3].fillna(media3)

# %% [markdown]
# - Visualizza la distribuzione dell'età per classe

# %%
data = df[['Age', 'Pclass']].copy()
sns.boxplot(data, x='Pclass', y='Age')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# - Visualizza la distribuzione dell'età per classe dividendo e mmostrando insieme i dati di uomini e donne

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(data= df, x='Pclass', y='Age', hue='Sex')
plt.title("Distribuzione dell'età per classe divisa per genere")
# Out:
# Text(0.5, 1.0, "Distribuzione dell'età per classe divisa per genere")

# %% [markdown]
# ## 3. Analisi del Dataset Iris
#
# - Esplora la distribuzione delle specie (conta quanti campioni ci sono per specie)
# - Calcola la lunghezza e la larghezza media dei petali per specie
# - Visualizza le dimensioni dei petali per specie (scatterplot)
# - Crea una nuova colonna per l'area del petalo e analizzala
# - Grafico della distribuzione dell'area del petalo per specie (boxplot)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# - Esplora la distribuzione delle specie (conta quanti campioni ci sono per specie)

# %%
setosaN = len(df[df['species'] == 'setosa'])
versicolorN = len(df[df['species'] == 'versicolor'])
virginicaN = len(df[df['species'] == 'virginica'])
print(f"Setosa: {setosaN}")
print(f"Versicolor: {versicolorN}")
print(f"Virginica: {virginicaN}")
# Out:
# Setosa: 50
# Versicolor: 50
# Virginica: 50

# %% [markdown]
# - Calcola la lunghezza e la larghezza media dei petali per specie

# %%
species = df['species'].unique()
for specie in species:
    lunghezzaMedia = df[df['species'] == specie]['sepal_length'].mean()
    larghezzaMedia = df[df['species'] == specie]['sepal_width'].mean()
    print(f"{specie}: len: {lunghezzaMedia:.2f}, wid: {larghezzaMedia:.2f}")
# Out:
# setosa: len: 5.01, wid: 3.43
# versicolor: len: 5.94, wid: 2.77
# virginica: len: 6.59, wid: 2.97

# %% [markdown]
# - Visualizza le dimensioni dei petali per specie (scatterplot)

# %%
import matplotlib.pyplot as plt
for specie in species:
    plt.figure(figsize=(8, 6))
    plt.title(f'Distribuzione sepali per {specie}')
    plt.scatter(x=df[df['species'] == specie]['sepal_length'], y=df[df['species'] == specie]['sepal_width'])
    plt.xlabel('sepal_length')
    plt.ylabel('sepal_width')
    plt.grid(True)

# %% [markdown]
# - Crea una nuova colonna per l'area del petalo e analizzala

# %%
df['Area'] = df['petal_length'] * df['petal_width']
#df.sample(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species   Area
# 112           6.8          3.0           5.5          2.1   virginica  11.55
# 45            4.8          3.0           1.4          0.3      setosa   0.42
# 60            5.0          2.0           3.5          1.0  versicolor   3.50
# 116           6.5          3.0           5.5          1.8   virginica   9.90
# 15            5.7          4.4           1.5          0.4      setosa   0.60
# 65            6.7          3.1           4.4          1.4  versicolor   6.16
# 126           6.2          2.8           4.8          1.8   virginica   8.64
# 52            6.9          3.1           4.9          1.5  versicolor   7.35
# 107           7.3          2.9           6.3          1.8   virginica  11.34
# 109           7.2          3.6           6.1          2.5   virginica  15.25

# %% [markdown]
# - Grafico della distribuzione dell'area del petalo per specie (boxplot)

# %%
sns.boxplot(x=df['species'], y=df['Area'])
# Out:
# <Axes: xlabel='species', ylabel='Area'>
